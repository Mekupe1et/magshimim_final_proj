# %% [markdown]
# https://huggingface.co/datasets/storytracer/LoC-PD-Books

# %%
import pandas as pd
temp = None
for i in range(1,8):
    df = pd.read_parquet(f"../base_dbs/LoC-PD-Books/train_0000{i}.parquet")
    df["category"] = "book"
    temp = pd.concat([temp, df], ignore_index=True)
temp
# Out:
#              lccn                                              title  \
# 0        24024079                                     Faith at work,
# 1        17023956  Straws from the manager; or, Thoughts on Chris...
# 2     unk81039814                            A Christmas meditation.
# 3     unk81010574                                   Bethlehem bells.
# 4        09022920                                Christmas builders,
# ...           ...                                                ...
# 6803     24000553  Tribute to old Lancaster, city--county, Pennsy...
# 6804     01016609                               Lancaster townstead.
# 6805     07018194  An outline history of a church; a memorial of ...
# 6806     09012040            Lansdowne past and present, 1888. 1908.
# 6807     24015023  The history of St. John's Reformed Church, 185...
#
#                                    author  year  page_count  \
# 0     Trowbridge, Gertrude Mary (Sherman)  1924          88
# 1                     Cotter, James Henry  1917         118
# 2                        Gilman, Lawrence  1916          32
# 3                          Hoadley, B. J.  1912          72
# 4               Jefferson, Charles Edward  1909          56
# ...                                   ...   ...         ...
# 6803                      Riddle, William  1908         154
# 6804                 Sener, Samuel Miller  1901          18
# 6805      Whitteker, John E. (John Edwin)  1905          48
# 6806             Johnson, George Caldwell  1908         104
# 6807   Ranck, Henry H. (Henry Haverstick)  1901         276
#
#                               filename  \
# 0           faithatwork00trow_djvu.txt
# 1      strawsfrommanage00cott_djvu.txt
# 2      christmasmeditat00gilm_djvu.txt
# 3         bethlehembell00hoad_djvu.txt
# 4      christmasbuilder00jeff_djvu.txt
# ...                                ...
# 6803   tributetooldlanc00ridd_djvu.txt
# 6804  lancastertownste00sener_djvu.txt
# 6805  outlinehistoryof00whitt_djvu.txt
# 6806   lansdownepastpre00john_djvu.txt
# 6807   historyofstjohns00ranc_djvu.txt
#
#                                                    text category
# 0     \n\n\n\nClass _ BN/'W *5 \n\nBook_ ‘AH _ \n\nC...     book
# 1     \nClass \n\nBook \n\n\n\nCOPYRIGHT DEPOSIE \n\...     book
# 2     . \n\n\n\n\nmm$ \n\n\n\nA CHIUSTMAS \nMEDITATI...     book
# 3     \n\n\nB V \n\n45 \n\n\n\n\n\nClass \n\nBook \n...     book
# 4     BV \n\n\n\n45 CHRISTMAS \n^^'^ BUILDERS \n\n\n...     book
# ...                                                 ...      ...
# 6803  \nR 1 D D i. E \n\n\n\n\n\n\n\n\n^<Wt7^<^-t^-,...     book
# 6804  # \n\n\n\n\n\nz^^-^ \n\n\n\nF 159 \n.L2 S5 \nC...     book
# 6805  F 159 \n.L2 W6 \nCopy 1 \n\n\n\n\nThe 175th An...     book
# 6806  \n\n\n\n\nXans^ownc \n\npast \n\n\n\nan6 \n\n\...     book
# 6807  \nass. \n\n\n\nPRi:;sENTi:n r,Y \n\n\n\n-r- ' ...     book
#
# [6808 rows x 8 columns]

# %%
temp = temp[['text', 'year', 'category']]
temp["decade"] = (temp["year"] // 10) * 10
temp["language_type"] = "written"
temp
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9628\2801307969.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["decade"] = (temp["year"] // 10) * 10
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_9628\2801307969.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["language_type"] = "written"
#                                                    text  year category  \
# 0     \n\n\n\nClass _ BN/'W *5 \n\nBook_ ‘AH _ \n\nC...  1924     book
# 1     \nClass \n\nBook \n\n\n\nCOPYRIGHT DEPOSIE \n\...  1917     book
# 2     . \n\n\n\n\nmm$ \n\n\n\nA CHIUSTMAS \nMEDITATI...  1916     book
# 3     \n\n\nB V \n\n45 \n\n\n\n\n\nClass \n\nBook \n...  1912     book
# 4     BV \n\n\n\n45 CHRISTMAS \n^^'^ BUILDERS \n\n\n...  1909     book
# ...                                                 ...   ...      ...
# 6803  \nR 1 D D i. E \n\n\n\n\n\n\n\n\n^<Wt7^<^-t^-,...  1908     book
# 6804  # \n\n\n\n\n\nz^^-^ \n\n\n\nF 159 \n.L2 S5 \nC...  1901     book
# 6805  F 159 \n.L2 W6 \nCopy 1 \n\n\n\n\nThe 175th An...  1905     book
# 6806  \n\n\n\n\nXans^ownc \n\npast \n\n\n\nan6 \n\n\...  1908     book
# 6807  \nass. \n\n\n\nPRi:;sENTi:n r,Y \n\n\n\n-r- ' ...  1901     book
#
#       decade language_type
# 0       1920       written
# 1       1910       written
# 2       1910       written
# 3       1910       written
# 4       1900       written
# ...      ...           ...
# 6803    1900       written
# 6804    1900       written
# 6805    1900       written
# 6806    1900       written
# 6807    1900       written
#
# [6808 rows x 5 columns]

# %%
import processor
processor.process_db(temp.copy(), "LoC-PD-Books")
# Out:
# Writing C:\Users\ADMIN\Desktop\code\magshimim_final\processed_dbs\LoC-PD-Books.parquet
# Successfully saved to: C:\Users\ADMIN\Desktop\code\magshimim_final\processed_dbs\LoC-PD-Books.parquet
#                                                        text  year category  \
# 0                  Printed in the United States of America   1924     book
# 1           In recent healing cults that claim to be based   1924     book
# 2         upon the Bible, yet whose tenets are so confused   1924     book
# 3            by extraneous comment that such foundation is   1924     book
# 4         regular attendance on their services and a yea...  1924     book
# ...                                                     ...   ...      ...
# 26585188                   "Bright Light in the Clouds" 60   1901     book
# 26585189                      In the Methodist Ministry 72   1901     book
# 26585190                   In the Presbyterian Ministry 73   1901     book
# 26585191          "Prayers in Times of National Tumult" 63   1901     book
# 26585192                     On "Future of St. John's" 244   1901     book
#
#           decade language_type  text_length
# 0           1920       written        78794
# 1           1920       written        78794
# 2           1920       written        78794
# 3           1920       written        78794
# 4           1920       written        78794
# ...          ...           ...          ...
# 26585188    1900       written       403766
# 26585189    1900       written       403766
# 26585190    1900       written       403766
# 26585191    1900       written       403766
# 26585192    1900       written       403766
#
# [26585193 rows x 6 columns]
