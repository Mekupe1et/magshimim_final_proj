# %%
import pandas as pd
df = pd.DataFrame({"decade": [], "year": [], "text": [], "category": []})

# %%
# df.to_parquet("large_dataset.parquet")

# %%
df = pd.read_parquet("large_dataset.parquet")
df
# Out:
#           date                                               text  decade  \
# 0       2023.0  Ahmed Abdel Mougod Soliman (born 19 December 1...  2020.0
# 1       1937.0  asked the Chancellor of the Exchequer whether ...  1930.0
# 2       2022.0  HAL is a multi-disciplinary open access archiv...  2020.0
# 3       2011.0  CALIFORNIA AIR RESOURCES BOARD \n\nSIP COMPLET...  2010.0
# 4       2017.0  Which assumptions about the variance need to h...  2010.0
# ...        ...                                                ...     ...
# 217610     NaN  \nR 1 D D i. E \n\n\n\n\n\n\n\n\n^<Wt7^<^-t^-,...  1900.0
# 217611     NaN  # \n\n\n\n\n\nz^^-^ \n\n\n\nF 159 \n.L2 S5 \nC...  1900.0
# 217612     NaN  F 159 \n.L2 W6 \nCopy 1 \n\n\n\n\nThe 175th An...  1900.0
# 217613     NaN  \n\n\n\n\nXans^ownc \n\npast \n\n\n\nan6 \n\n\...  1900.0
# 217614     NaN  \nass. \n\n\n\nPRi:;sENTi:n r,Y \n\n\n\n-r- ' ...  1900.0
#
#        category    year
# 0          None     NaN
# 1          None     NaN
# 2          None     NaN
# 3          None     NaN
# 4          None     NaN
# ...         ...     ...
# 217610     book  1908.0
# 217611     book  1901.0
# 217612     book  1905.0
# 217613     book  1908.0
# 217614     book  1901.0
#
# [217615 rows x 5 columns]

# %%
df.shape
# Out:
# (153812, 4)

# %%
import seaborn as sns
sns.histplot(data=df, x="year", bins=range(int(df['year'].min()), int(df['year'].max()), 1))
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
df_2000 = df[df["decade"] >= 2000]

# %%
sns.histplot(data=df, x="decade", bins=range(int(df['decade'].min()), int(df['decade'].max()), 10))
# Out:
# <Axes: xlabel='decade', ylabel='Count'>

# %%
s= """adasd


dasda

dasdas
adsd""".split('\n')
# s = [item for item in s if item != ""]
s
# Out:
# ['adasd', '', '', 'dasda', '', 'dasdas', 'adsd']
