# %%
import pandas as pd
df = pd.DataFrame({"decade": [], "year": [], "text": [], "category": []})

# %%
# df.to_parquet("large_dataset.parquet")

# %%
df = pd.read_parquet("large_dataset.parquet")
df
# Out:
#           date                                               text  decade  \
# 0       1993.0  Combined bassinet liner and organizer\n\n\n\nF...  1990.0
# 1       1942.0  LESLIE, Chief Justice.\nW. R. Sharrock institu...  1940.0
# 2       1951.0  TONIGHT AND THURSDAY Shows 7:25-9:30 1 Feature...  1950.0
# 3       1984.0  Petitions for relief from personal restraint. ...  1980.0
# 4       1980.0  In re Dann Deaver, applying for supervisory an...  1980.0
# ...        ...                                                ...     ...
# 173807     NaN  \nR 1 D D i. E \n\n\n\n\n\n\n\n\n^<Wt7^<^-t^-,...  1900.0
# 173808     NaN  # \n\n\n\n\n\nz^^-^ \n\n\n\nF 159 \n.L2 S5 \nC...  1900.0
# 173809     NaN  F 159 \n.L2 W6 \nCopy 1 \n\n\n\n\nThe 175th An...  1900.0
# 173810     NaN  \n\n\n\n\nXans^ownc \n\npast \n\n\n\nan6 \n\n\...  1900.0
# 173811     NaN  \nass. \n\n\n\nPRi:;sENTi:n r,Y \n\n\n\n-r- ' ...  1900.0
#
#        category    year
# 0          None     NaN
# 1          None     NaN
# 2          None     NaN
# 3          None     NaN
# 4          None     NaN
# ...         ...     ...
# 173807     book  1908.0
# 173808     book  1901.0
# 173809     book  1905.0
# 173810     book  1908.0
# 173811     book  1901.0
#
# [173812 rows x 5 columns]

# %%
df.shape
# Out:
# (153812, 4)

# %%
import seaborn as sns
sns.histplot(data=df, x="year", bins=range(int(df['year'].min()), int(df['year'].max()), 1))
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
df_2000 = df[df["decade"] >= 2000]

# %%
sns.histplot(data=df, x="decade", bins=range(int(df['decade'].min()), int(df['decade'].max()), 10))
# Out:
# array([None, 'tweet', 'book'], dtype=object)
