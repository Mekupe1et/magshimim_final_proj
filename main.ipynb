# %%
import pandas as pd
df = pd.read_parquet(".idea/data/processed_dbs/combined_dataset.parquet")
df
# Out:
#           year language_type  \
# 0         2023       Written
# 1         2023       Written
# 2         1937        Spoken
# 3         2022       Written
# 4         2022       Written
# ...        ...           ...
# 36431782  2025       written
# 36431783  2025       written
# 36431784  2024       written
# 36431785  2025       written
# 36431786  2025       written
#
#                                                        text  decade  \
# 0         Ahmed Abdel Mougod Soliman (born 19 December 1...    2020
# 1         Athletes (track and field) at the 2000 Summer ...    2020
# 2         asked the Chancellor of the Exchequer whether ...    1930
# 3         HAL is a multi-disciplinary open access archiv...    2020
# 4         Abstract. Image Retrieval is commonly evaluate...    2020
# ...                                                     ...     ...
# 36431782                  Good morning Sir Jai Jagannath 🙏🙏    2020
# ...

# %%
df.shape
# Out:
# (36431787, 6)

# %%
import seaborn as sns
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
sns.histplot(data=df, x="year", bins=range(int(df['year'].min()), int(df['year'].max()), 1) , log=True)
# Out:
# <Axes: xlabel='year', ylabel='Count'>

# %%
sns.histplot(data=df, x="year", bins=range(int(df['year'].min()), int(df['year'].max()), 1))
# Out:
# <Axes: xlabel='year', ylabel='Count'>
